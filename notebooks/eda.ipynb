# %%
from dotenv import load_dotenv
import os

load_dotenv()   # 👈 REQUIRED

print(os.getenv("OPENAI_API_KEY"))
# Out:
# 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

# %%
print(os.getenv("GOOGLE_API_KEY"))
# Out:
# None

# %%
from google import genai

# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client(api_key="AIzaSyD8-p7bp0nBUL1dQi7B1bEk0BXwByamXOM")
# client = genai.Client(api_key="GEMINI_API_KEY")

response = client.models.generate_content(
    model="gemini-3-flash-preview", contents="Explain how AI works in a few words"
)
print(response.text)
# Out:
# AI works by **finding patterns in data** to make decisions or predictions.

# %%
response = client.models.generate_content_stream(
    model="gemini-3-flash-preview",
    contents=["Explain how AI works"]
)
for chunk in response:
    print(chunk.text, end="")
# Out:
# To understand how Artificial Intelligence (AI) works, it helps to stop thinking of it as a "robot brain" and start thinking of it as **advanced pattern recognition.**
#
# At its simplest, AI is a field of computer science that builds systems capable of performing tasks that usually require human intelligence—like recognizing faces, translating languages, or making decisions.
#
# Here is the step-by-step breakdown of how it actually functions.
#
# ---
#
# ### 1. The Foundation: Data
# AI cannot "think" on its own; it needs to be taught. This teaching is done using massive amounts of **data**.
# *   If you want an AI to recognize a cat, you show it millions of pictures of cats.
# *   If you want an AI to write like a human, you feed it almost every book and article on the internet.
#
# ### 2. The Engine: Machine Learning (ML)
# Machine Learning is the most common method used to create AI today. In traditional programming, a human writes specific rules: *"If the animal has whiskers and pointed ears, call it a cat."*
#
# In **Machine Learning**, we don't give the computer rules. Instead, we give it an **algorithm** (a mathematical formula) and the data. The computer looks at the data and figures out the rules for itself.
#
# ### 3. The Structure: Neural Networks
# Most modern AI (like ChatGPT or Midjourney) uses something called **Artificial Neural Networks**. These are inspired by the human brain.
#
# A neural network is made of layers of "nodes" (mathematical functions).
# *   **Input Layer:** Takes in the data (e.g., the pixels of an image).
# *   **Hidden Layers:** These layers analyze the data. One layer might look for lines, the next for shapes, and the next for textures.
# *   **Output Layer:** Gives the final answer (e.g., "This is a cat").
#
# ### 4. The Process: Training and Feedback
# When an AI is being "trained," it makes a guess. At first, its guesses are terrible.
# 1.  **Prediction:** The AI looks at a picture of a dog and guesses "Toaster."
# 2.  **Error Calculation:** The system is told, "No, that’s a dog."
# 3.  **Adjustment:** The AI adjusts its internal mathematical connections (called **weights**) to be slightly more accurate next time.
#
# After repeating this billions of times, the AI becomes incredibly accurate at identifying patterns.
#
# ### 5. Prediction vs. Understanding
# This is the most important part to remember: **AI does not "know" what it is saying.**
#
# When you ask an AI like ChatGPT a question, it isn't "thinking" about the meaning. Instead, it is calculating **probabilities**. It looks at the words you typed and asks itself: *"Based on all the text I have ever read, what is the most statistically likely word to come next?"* It builds its answer one word at a time based on math, not consciousness.
#
# ---
#
# ### Summary: The "Recipe" for AI
# To build an AI, you need three things:
# 1.  **Algorithms:** The mathematical instructions.
# 2.  **Compute Power:** Powerful computers (GPUs) to run the math.
# 3.  **Data:** The "textbooks" the AI uses to learn patterns.
#
# **In short:** AI works by taking massive amounts of data, using math to find patterns in that data, and then using those patterns to make a prediction about new information.

# %%
.\.venv\Scripts\Activate.ps1
