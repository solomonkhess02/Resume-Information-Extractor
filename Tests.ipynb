# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve().parents[1]
sys.path.append(str(PROJECT_ROOT))

# %%
from src.resume_loader import extract_text_from_pdf
from src.preprocessing import clean_resume
from src.llm_extractor import extract_resume_info
from src.llm_classifier import classify_resume

text = extract_text_from_pdf("data/resumes/Resume_1.8(IIT).pdf")
text = clean_resume(text)

info = extract_resume_info(text)
classification = classify_resume(text)

print(info)
print(classification)
# Out:
# name='Solomon Khess' email='21mm02001@iitbbs.ac.in' phone=None skills=['Python', 'C++', 'C', 'SQL', 'Origin', 'Excel', 'Git', 'Jupyter Notebook', 'VS Code', 'MLOps', 'AWS', 'TensorFlow', 'Keras', 'Scikit-Learn', 'NumPy', 'Pandas', 'Matplotlib', 'Seaborn', 'Machine Learning', 'Process Control', 'Computer Vision', 'Process Automation'] years_of_experience=0 education='B.Tech And M.Tech (Dual Degree) Metallurgical And Materials Engineering, Indian Institute of Technology Bhubaneswar' previous_roles=['Research Intern at NTPC', 'Research Intern at SMFA', 'Trainee at Rashtriya Ispat Nigam Ltd']
# domain='ML Engineer' seniority='Fresher' fit_score=0.85
